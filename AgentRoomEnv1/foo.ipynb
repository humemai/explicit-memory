# %%
from explicit_memory.utils import positional_encoding

# %%
import matplotlib.pyplot as plt

plt.imshow(positional_encoding(100, 64, 10000, False), vmax=1.0, vmin=-1.0)

# %%
import matplotlib.pyplot as plt

plt.imshow(positional_encoding(16, 64, 10000, False), vmax=1.0, vmin=-1.0)

# %%
import matplotlib.pyplot as plt

plt.imshow(positional_encoding(32, 64, 10000, False), vmax=1.0, vmin=-1.0)

# %%
positional_encoding(32, 64, 10000, True)[0].shape
# Out:
# torch.Size([64])

# %%
0.99**6
# Out:
# 0.941480149401

# %%
1 / (1-0.941480149401)
# Out:
# 17.08821860897041
