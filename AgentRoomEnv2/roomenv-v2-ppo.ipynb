# %% [markdown]
# ## Explore

# %%
from glob import glob
from explicit_memory.utils import read_yaml
import pandas as pd
import numpy as np

results_all = []
for results_path in glob("./training_results/PPO/explore/LSTM/s/*/results.yaml"):
    train_path = results_path.replace("results.yaml", "train.yaml")
    train = read_yaml(train_path)
    results = read_yaml(results_path)
    results_all.append(
        {
            "num_episodes": train["num_episodes"],
            "num_rollouts": train["num_rollouts"],
            "epoch_per_rollout": train["epoch_per_rollout"],
            "gamma": train["gamma"],
            "batch_size": train["batch_size"],
            "epsilon": train["epsilon"],
            "entropy_weight": train["entropy_weight"],
            "tau": train["tau"],
            "test_score": results["test_score"]["mean"],
            "val_score": max([foo["mean"] for foo in results["validation_score"]]),
            "path": results_path.split("/")[-2],
        }
    )

df = pd.DataFrame(results_all)
df_sorted = df.sort_values(by="test_score", ascending=False)
print(f"number of training results: {len(df_sorted)}")

top_k = 10
df_sorted[:top_k]
# Out:
# number of training results: 48
#     num_episodes  num_rollouts  epoch_per_rollout     gamma  batch_size  \
# 9             10            10                 64  0.920597           8
# 13            20            20                 16  0.583264           8
# 46            20            20                 32  0.671473           8
# 40            20            20                 32  0.852593           8
# 39            20            20                 64  0.930110           8
# 38            20            20                 32  0.653656           8
# 7             20            20                 16  0.536671           8
# 36            20            20                 32  0.671021           8
# 21            10            10                 32  0.915594           8
# 1             20            20                 32  0.665172           8
#
#     epsilon  entropy_weight   tau  test_score  val_score  \
# 9       0.2        0.361795  0.93       659.5      740.6
# 13      0.2        0.013287  0.93       594.1      694.0
# 46      0.2        0.035405  0.93       518.5      682.1
# 40      0.2        0.076833  0.93       518.5      655.1
# 39      0.2        0.485659  0.93       518.5      527.7
# 38      0.2        0.016617  0.93       518.5      445.8
# 7       0.2        0.030837  0.93       518.5      567.9
# 36      0.2        0.045817  0.93       518.5      751.5
# 21      0.2        0.244205  0.93       518.5      594.6
# 1       0.2        0.033631  0.93       518.5      682.1
#
#                           path
# 9   2024-03-04 13:31:41.203765
# 13  2024-03-04 14:32:31.708967
# 46  2024-03-04 14:16:05.050180
# 40  2024-03-04 13:49:50.256336
# 39  2024-03-04 13:51:02.934742
# 38  2024-03-04 14:33:44.277205
# 7   2024-03-04 14:10:13.828523
# 36  2024-03-04 14:13:13.505272
# 21  2024-03-04 13:25:16.587624
# 1   2024-03-04 14:02:49.866091

# %%
df_sorted[:top_k].select_dtypes(include=[np.number]).mean()
# Out:
# num_episodes          18.000000
# num_rollouts          18.000000
# epoch_per_rollout     35.200000
# gamma                  0.740015
# batch_size             8.000000
# epsilon                0.200000
# entropy_weight         0.134409
# tau                    0.930000
# test_score           540.160000
# val_score            634.140000
# dtype: float64

# %%
df_sorted[-top_k:].select_dtypes(include=[np.number]).mean()
# Out:
# num_episodes          14.000000
# num_rollouts          14.000000
# epoch_per_rollout     36.800000
# gamma                  0.740311
# batch_size             8.000000
# epsilon                0.200000
# entropy_weight         0.145203
# tau                    0.930000
# test_score           172.700000
# val_score            197.000000
# dtype: float64

# %% [markdown]
# ## MM

# %%
from glob import glob
from explicit_memory.utils import read_yaml
import pandas as pd
import numpy as np

results_all = []
for results_path in glob("./training_results/PPO/mm/LSTM/s/*/results.yaml"):
    train_path = results_path.replace("results.yaml", "train.yaml")
    train = read_yaml(train_path)
    results = read_yaml(results_path)
    results_all.append(
        {
            "num_episodes": train["num_episodes"],
            "num_rollouts": train["num_rollouts"],
            "epoch_per_rollout": train["epoch_per_rollout"],
            "gamma": train["gamma"],
            "batch_size": train["batch_size"],
            "epsilon": train["epsilon"],
            "entropy_weight": train["entropy_weight"],
            "tau": train["tau"],
            "split_reward_training": train["split_reward_training"],
            "test_score": results["test_score"]["mean"],
            "val_score": max([foo["mean"] for foo in results["validation_score"]]),
            "path": results_path.split("/")[-2],
        }
    )

df = pd.DataFrame(results_all)
df_sorted = df.sort_values(by="test_score", ascending=False)
print(f"number of training results: {len(df_sorted)}")

top_k = 10
df_sorted[:top_k]
# Out:
# number of training results: 90
#     num_episodes  num_rollouts  epoch_per_rollout     gamma  batch_size  \
# 42            10             5                 16  0.982625           8
# 38            10            10                 16  0.987418           8
# 10            10            10                 32  0.926026          32
# 16            10            20                 16  0.966896          16
# 48            10            20                 64  0.905213          16
# 1             10            20                  8  0.918732           8
# 9             10             5                 16  0.973576          16
# 79            10             5                 32  0.990241           8
# 14            10            10                 16  0.961367           8
# 64            10            10                 32  0.936878           8
#
#     epsilon  entropy_weight   tau  split_reward_training  test_score  \
# 42      0.2        0.094691  0.93                  False       830.0
# 38      0.2        0.032658  0.93                  False       794.4
# 10      0.2        0.017090  0.93                   True       788.4
# 16      0.2        0.006873  0.93                  False       774.0
# 48      0.2        0.004750  0.93                  False       767.2
# 1       0.2        0.013955  0.93                   True       767.1
# 9       0.2        0.032107  0.93                   True       752.1
# 79      0.2        0.081392  0.93                   True       727.2
# 14      0.2        0.031330  0.93                  False       711.4
# 64      0.2        0.028375  0.93                  False       709.4
#
#     val_score                        path
# 42      689.1  2024-03-04 10:24:04.727747
# 38      581.2  2024-03-04 12:27:29.829646
# 10      726.9  2024-03-04 10:48:02.554893
# 16      520.0  2024-03-04 12:39:36.176969
# 48      686.0  2024-03-04 10:03:18.880292
# 1       600.9  2024-03-04 10:22:55.084595
# 9       659.0  2024-03-04 11:46:47.327109
# 79      503.0  2024-03-04 12:41:08.378212
# 14      674.8  2024-03-04 11:32:41.550455
# 64      491.6  2024-03-04 10:17:06.416677

# %%
df_sorted[:top_k].select_dtypes(include=[np.number]).median()
# Out:
# num_episodes          10.000000
# num_rollouts          10.000000
# epoch_per_rollout     24.000000
# gamma                  0.954536
# batch_size             8.000000
# epsilon                0.200000
# entropy_weight         0.029853
# tau                    0.930000
# test_score           759.600000
# val_score            666.900000
# dtype: float64

# %%
df_sorted[:top_k].select_dtypes(include=[np.number]).mean()
# Out:
# num_episodes          10.000000
# num_rollouts          11.500000
# epoch_per_rollout     24.800000
# gamma                  0.954897
# batch_size            12.800000
# epsilon                0.200000
# entropy_weight         0.034322
# tau                    0.930000
# test_score           762.120000
# val_score            613.250000
# dtype: float64

# %%
top_k = 10
df_sorted[-top_k:]
# Out:
#     num_episodes  num_rollouts  epoch_per_rollout     gamma  batch_size  \
# 38            10            10                  4  0.973388          32
# 13            10            50                  8  0.922868           8
# 47            10             5                  8  0.953923          64
# 46            10             5                 16  0.935459          64
# 63            10             5                  8  0.965219          32
# 20            10            10                  4  0.944083          16
# 61            10            20                 32  0.943515          16
# 24            10             5                 32  0.973892          32
# 41            10             5                  4  0.959442           8
# 34            10             5                  4  0.990239           8
#
#     epsilon  entropy_weight   tau  split_reward_training  test_score  \
# 38      0.2        0.083553  0.93                  False       339.5
# 13      0.2        0.091613  0.93                   True       339.5
# 47      0.2        0.020150  0.93                  False       339.5
# 46      0.2        0.062494  0.93                  False       339.5
# 63      0.2        0.094691  0.93                   True       339.1
# 20      0.2        0.052377  0.93                   True       339.1
# 61      0.2        0.025201  0.93                  False       334.4
# 24      0.2        0.006537  0.93                  False       289.2
# 41      0.2        0.048885  0.93                  False       162.9
# 34      0.2        0.068885  0.93                   True        95.4
#
#     val_score                        path
# 38      446.5  2024-03-04 10:45:49.924939
# 13      409.2  2024-03-04 10:40:11.553908
# 47      520.8  2024-03-04 10:45:07.080757
# 46      520.8  2024-03-04 11:48:41.803476
# 63      484.6  2024-03-04 10:38:33.437266
# 20      443.4  2024-03-04 12:12:52.668551
# 61      507.8  2024-03-04 10:46:35.126642
# 24      355.7  2024-03-04 11:14:50.641405
# 41      164.0  2024-03-04 10:39:25.992493
# 34      304.9  2024-03-04 11:07:57.392812

# %%
df_sorted[-top_k:].select_dtypes(include=[np.number]).median()
# Out:
# num_episodes          10.000000
# num_rollouts           5.000000
# epoch_per_rollout      8.000000
# gamma                  0.956683
# batch_size            24.000000
# epsilon                0.200000
# entropy_weight         0.057435
# tau                    0.930000
# test_score           339.100000
# val_score            444.950000
# dtype: float64

# %%
df_sorted[-top_k:].select_dtypes(include=[np.number]).mean()
# Out:
# num_episodes          10.000000
# num_rollouts          12.000000
# epoch_per_rollout     12.000000
# gamma                  0.956203
# batch_size            28.000000
# epsilon                0.200000
# entropy_weight         0.055439
# tau                    0.930000
# test_score           291.810000
# val_score            415.770000
# dtype: float64
