# %% [markdown]
# # 27-Nov-2023
#
# Check for the terminal state: `q(s, a) = r + 0`. This might have been causing some issues
# I didn't really specify the terminal state by enforcing `done`, and that's why the
# q-values were not decreasing towards 1, as it makes decisions. The below plot shows
# the experiments carried out on RoomEnv-v1, our previous paper:
#
# Training for 32 episodes (15-Nov-2023), with the mistake
# - total average test rewards: 93.5 +- 3.8
#
# Training for 32 episodes (27-Nov-2023), mistake corrected
# - total average test rewards: 92.2 +- 9.5
#
# Actually the results are quite similar except, that the plot looks better now ...\
# The agents don't get the same observation at every time step, so there is randomness.
#
# - left is before and right is after corrected
# - action 0: move the short-term memory to the episodic
# - action 1: move the short-term memory to the semantic
# - action 2: forget it

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
